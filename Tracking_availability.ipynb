# %% [markdown]
# Get a list of all stations:

# %%
import json
import requests

url_stations = 'http://barcelonaapi.marcpous.com/bicing/stations.json'
res_stations = requests.get(url_stations)
stations = json.loads(res_stations.text)

# %% [markdown]
# Arrange the data to be in lists:

# %%
station_id = []
station_name = []
station_lat = []
station_lon = []

for idx,i in enumerate(stations['data']['bici']):
    station_id.append(int(stations['data']['bici'][idx]['id']))
    station_name.append(stations['data']['bici'][idx]['name'])
    station_lat.append(float(stations['data']['bici'][idx]['lat']))
    station_lon.append(float(stations['data']['bici'][idx]['lon']))

# %% [markdown]
# Find out how many bikes are available at each of the selected stations:

# %%
import datetime

bikes = []
slots = []
dates = []
bikes_ok = []
slots_ok = []

for i in station_id:
    url_availability = 'http://wservice.viabicing.cat/v2/stations/'+str(i)
    res_availability = requests.get(url_availability)
    json_availability = json.loads(res_availability.text)
    
    try:
        bikes_num = json_availability['stations'][0]['bikes']
        slots_num = json_availability['stations'][0]['slots']
        dates.append(datetime.datetime.fromtimestamp(json_availability['updateTime']).strftime('%Y-%m-%d %H:%M:%S'))
    except:
        bikes_num = 0
        slots_num = 0
        
        try: 
            dates.append(dates[len(dates)-1])
        except:
            dates.append(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
            
    bikes.append(bikes_num)
    slots.append(slots_num)
    
    if int(bikes_num) >= 2:
        bikes_ok.append(True)
    else:
        bikes_ok.append(False)
        
    if int(slots_num) >= 2:
        slots_ok.append(True)
    else:
        slots_ok.append(False)

# %% [markdown]
# Create a dataframe so that we can easily filter out the non-available stations:

# %%
import pandas as pd
dataset = pd.DataFrame({'station_id':station_id,
                        'station_name':station_name,
                        'station_lat':station_lat,
                        'station_lon':station_lon,
                        'bikes':bikes,
                        'slots':slots,
                        'bikes_ok':bikes_ok,
                        'slots_ok':slots_ok,
                        'entry_date':dates
                       })
dataset.head(10)
# Out:
#     bikes bikes_ok           entry_date slots slots_ok  station_id  \
# 0      25     True  2018-08-03 17:42:08     1    False           1
# 1       0    False  2018-08-03 17:42:08     0    False          10
# 2       9     True  2018-08-03 17:42:08     9     True         100
# 3      11     True  2018-08-03 17:42:08    15     True         101
# 4       7     True  2018-08-03 17:42:08    17     True         102
# 5      14     True  2018-08-03 17:42:08     7     True         103
# 6      26     True  2018-08-03 17:42:08     0    False         104
# 7      11     True  2018-08-03 17:42:08     8     True         105
# 8       1    False  2018-08-03 17:42:08    16     True         106
# 9       0    False  2018-08-03 17:42:08    21     True         107
# 10      6     True  2018-08-03 17:42:08    12     True         108
# 11      3     True  2018-08-03 17:42:08    16     True         109
# 12      8     True  2018-08-03 17:42:08    11     True          11
# 13      7     True  2018-08-03 17:42:08    12     True         110
# 14      1    False  2018-08-03 17:42:08    18     True         111
# 15     16     True  2018-08-03 17:42:08     2     True         112
# 16     22     True  2018-08-03 17:42:08     4     True         113
# 17      5     True  2018-08-03 17:42:08    12     True         114
# 18      0    False  2018-08-03 17:42:08    21     True         115
# 19      7     True  2018-08-03 17:42:08    19     True         116
# 20      9     True  2018-08-03 17:42:08    10     True         117
# 21     27     True  2018-08-03 17:42:08     0    False         118
# 22      6     True  2018-08-03 17:42:08    14     True         119
# 23      2     True  2018-08-03 17:42:08    26     True          12
# 24      8     True  2018-08-03 17:42:08    11     True         120
# 25      6     True  2018-08-03 17:42:08    13     True         121
# 26      8     True  2018-08-03 17:42:08    11     True         122
# 27      0    False  2018-08-03 17:42:08    18     True         123
# 28     23     True  2018-08-03 17:42:08     0    False         124
# 29      0    False  2018-08-03 17:42:08    18     True         125
# ..    ...      ...                  ...   ...      ...         ...
# 389     4     True  2018-08-03 17:42:08    15     True          71
# 390     0    False  2018-08-03 17:42:08    25     True          72
# 391     0    False  2018-08-03 17:42:08    19     True          73
# 392     1    False  2018-08-03 17:42:08    19     True          74
# 393     1    False  2018-08-03 17:42:08    18     True          75
# 394    13     True  2018-08-03 17:42:08    19     True          76
# 395     8     True  2018-08-03 17:42:08    15     True          78
# 396     0    False  2018-08-03 17:42:08    22     True          79
# 397    18     True  2018-08-03 17:42:08     5     True           8
# 398     4     True  2018-08-03 17:42:08    12     True          80
# 399    15     True  2018-08-03 17:42:08     3     True          81
# 400    17     True  2018-08-03 17:42:08    14     True          82
# 401     5     True  2018-08-03 17:42:08    19     True          83
# 402    13     True  2018-08-03 17:42:08     7     True          84
# 403    21     True  2018-08-03 17:42:08     0    False          85
# 404     1    False  2018-08-03 17:42:08    25     True          86
# 405     3     True  2018-08-03 17:42:08    15     True          87
# 406     0    False  2018-08-03 17:42:08    17     True          88
# 407     1    False  2018-08-03 17:42:08    25     True          89
# 408    10     True  2018-08-03 17:42:08    16     True           9
# 409     0    False  2018-08-03 17:42:08    18     True          90
# 410     6     True  2018-08-03 17:42:08    24     True          91
# 411     1    False  2018-08-03 17:42:08    13     True          92
# 412    11     True  2018-08-03 17:42:08     8     True          93
# 413     8     True  2018-08-03 17:42:08    13     True          94
# 414    17     True  2018-08-03 17:42:08    13     True          95
# 415     3     True  2018-08-03 17:42:08    16     True          96
# 416    13     True  2018-08-03 17:42:08     6     True          97
# 417    18     True  2018-08-03 17:42:08     3     True          98
# 418    19     True  2018-08-03 17:42:08     0    False          99
#
#      station_lat  station_lon                   station_name
# 0      41.397952     2.180042  Gran Via Corts Catalanes, 760
# 1      41.385531     2.183527              Pl. Comercial, 11
# 2      41.379135     2.144090                 Tarragona, 159
# 3      41.392988     2.143562              Av. Pau Casals, 1
# 4      41.393093     2.143365              Av. Pau Casals, 3
#
# [419 rows x 9 columns]

# %% [markdown]
# Import the *new* dataset into a SQL table:

# %%
import sqlite3
conn = sqlite3.connect("bicidb.db")
cursos = conn.cursor()

# %%
dataset.to_sql('historical_availability', con=conn, if_exists='append')

# %% [markdown]
# Load back the *full* dataset into a data frame:

# %%
import pandas as pd
pd.read_sql("SELECT DISTINCT(entry_date) FROM historical_availability;", con=conn)
# Out:
#               entry_date
# 0    2018-07-04 12:50:07
# 1    2018-07-11 22:17:07
# 2    2018-07-11 22:18:08
# 3    2018-07-11 22:19:08
# 4    2018-07-29 12:52:08
# 5    2018-07-29 15:14:08
# 6    2018-07-29 15:15:08
# 7    2018-07-29 15:19:08
# 8    2018-07-29 15:20:08
# 9    2018-07-29 15:29:07
# 10   2018-07-29 15:30:08
# 11   2018-07-29 15:39:08
# 12   2018-07-29 15:40:08
# 13   2018-07-29 15:49:08
# 14   2018-07-29 15:50:08
# 15   2018-07-29 15:59:08
# 16   2018-07-29 16:00:04
# 17   2018-07-29 16:00:15
# 18   2018-07-29 16:09:08
# 19   2018-07-29 16:10:08
# 20   2018-07-29 16:19:08
# 21   2018-07-29 16:20:08
# 22   2018-07-29 16:29:08
# 23   2018-07-29 16:30:08
# 24   2018-07-30 15:29:07
# 25   2018-07-30 15:30:09
# 26   2018-07-30 15:39:08
# 27   2018-07-30 15:40:08
# 28   2018-07-30 15:49:07
# 29   2018-07-30 15:50:08
# ..                   ...
# 346  2018-09-03 15:49:08
# 347  2018-09-03 15:50:08
# 348  2018-09-03 16:00:04
# 349  2018-09-04 13:59:07
# 350  2018-09-04 14:00:04
# 351  2018-09-04 14:09:08
# 352  2018-09-04 14:10:08
# 353  2018-09-04 14:19:08
# 354  2018-09-04 14:20:08
# 355  2018-09-04 14:29:08
# 356  2018-09-04 14:30:08
# 357  2018-09-04 14:39:07
# 358  2018-09-04 14:40:09
# 359  2018-09-04 14:49:08
# 360  2018-09-04 14:50:08
# 361  2018-09-04 14:59:08
# 362  2018-09-04 15:00:04
# 363  2018-09-04 15:00:15
# 364  2018-09-04 15:09:08
# 365  2018-09-04 15:10:08
# 366  2018-09-04 15:19:08
# 367  2018-09-04 15:20:08
# 368  2018-09-04 15:29:08
# 369  2018-09-04 15:30:08
# 370  2018-09-04 15:39:08
# 371  2018-09-04 15:40:08
# 372  2018-09-04 15:49:07
# 373  2018-09-04 15:50:08
# 374  2018-09-04 15:59:08
# 375  2018-09-04 16:00:04
#
# [376 rows x 1 columns]

# %% [markdown]
# Take the average availability of each station during morning hours and visualize it

# %% [markdown]
# Filter out stations that are not available:

# %%
dataset_clean_bikes = dataset[dataset.bikes_ok == True].reset_index(drop=True)
dataset_clean_bikes
