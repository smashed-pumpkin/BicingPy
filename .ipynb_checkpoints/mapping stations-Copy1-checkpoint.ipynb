# %% [markdown]
# #### 1. Investigate the data

# %% [markdown]
# Load the dataset (should be stored locally):

# %%
import sqlite3
conn = sqlite3.connect("bicidb.db")
cursos = conn.cursor()

import pandas as pd
df = pd.read_sql("SELECT * FROM historical_availability;", con=conn)

# %% [markdown]
# Take a first glance at the structure. We should have one observation for all bike locations (lat and lon) per date and time. Each observation contains the following information:
#
#  * **Station Name** - the name of the station, which corresponds to the street name and number on which it is located
#  * **Station Lat** - the latitude of the station
#  * **Station Lon** - the longitude of the station
#  * **Station ID** - the unique ID of the station
#  * **Bikes** - the number of available bikes at that time
#  * **Bikes OK** - a flag that indicated whether there are more than 1 bikes at that time (1=Y, 0=N)
#  * **Slots** - the number of available bike slots at that time
#  * **Slots OK** - a flag that indicated whether there are more than 1 slots at that time (1=Y, 0=N)
#  * **Entry Date** - the time at which the data was downloaded

# %%
df.head(5)
# Out:
#    index bikes  bikes_ok           entry_date slots  slots_ok  station_id  \
# 0      0    23         1  2018-07-04 12:50:07     1         0           1
# 1      1     0         0  2018-07-04 12:50:07     0         0          10
# 2      2    15         1  2018-07-04 12:50:07     6         1         100
# 3      3    18         1  2018-07-04 12:50:07     7         1         101
# 4      4    10         1  2018-07-04 12:50:07    10         1         102
#
#    station_lat  station_lon                   station_name
# 0    41.397952     2.180042  Gran Via Corts Catalanes, 760
# 1    41.385531     2.183527              Pl. Comercial, 11
# 2    41.379135     2.144090                 Tarragona, 159
# 3    41.392988     2.143562              Av. Pau Casals, 1
# 4    41.393093     2.143365              Av. Pau Casals, 3

# %% [markdown]
# Break out the entry date into separate date/time components to make it easier for analysis and exploration:

# %%
df['entry_date'] = pd.to_datetime(df['entry_date'])
df['entry_year'] = [x.year for x in df['entry_date']]
df['entry_month'] = [x.month for x in df['entry_date']]
df['entry_day'] = [x.day for x in df['entry_date']]
df['entry_hour'] = [x.hour for x in df['entry_date']]
df['entry_minute'] = [x.minute for x in df['entry_date']]
df['entry_weekday'] = [x.weekday() for x in df['entry_date']]
df.head(3)
# Out:
#    index bikes  bikes_ok          entry_date slots  slots_ok  station_id  \
# 0      0    23         1 2018-07-04 12:50:07     1         0           1
# 1      1     0         0 2018-07-04 12:50:07     0         0          10
# 2      2    15         1 2018-07-04 12:50:07     6         1         100
#
#    station_lat  station_lon                   station_name  entry_year  \
# 0    41.397952     2.180042  Gran Via Corts Catalanes, 760        2018
# 1    41.385531     2.183527              Pl. Comercial, 11        2018
# 2    41.379135     2.144090                 Tarragona, 159        2018
#
#    entry_month  entry_day  entry_hour  entry_minute  entry_weekday
# 0            7          4          12            50              2
# 1            7          4          12            50              2
# 2            7          4          12            50              2

# %% [markdown]
# Since the script has been run failry sporadically and we are interested in identifying the right time to pick up/drop off a bike, let's check how many observation are available per hour:

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

num_bins = len(df.entry_hour.unique())
n, bins, patches = plt.hist(df.entry_hour, num_bins, facecolor='green', alpha=0.5) # the alpha makes the colour lighter
plt.show()

# %% [markdown]
# Check the data types to make sure all metrics are integers:

# %%
df.dtypes
# Out:
# index                     int64
# bikes                    object
# bikes_ok                  int64
# entry_date       datetime64[ns]
# slots                    object
# slots_ok                  int64
# station_id                int64
# station_lat             float64
# station_lon             float64
# station_name             object
# entry_year                int64
# entry_month               int64
# entry_day                 int64
# entry_hour                int64
# entry_minute              int64
# entry_weekday             int64
# dtype: object

# %% [markdown]
# Fix the data types of some metrics:

# %%
df.slots = df.slots.astype(int)
df.bikes = df.bikes.astype(int)

# %% [markdown]
# Next, let's get a more holistic overview of the number of bikes available during our observation period using a calendar heatmap:

# %%
df_new = df.groupby(['entry_weekday','entry_hour'])['bikes'].mean()
df_new = df_new.reset_index(name="means")

# Pivot the dataframe to create a [hour x date] matrix containing means
import seaborn as sns #visualization library based on matplotlib
sns.heatmap(df_new.pivot("entry_hour", "entry_weekday", "means"), annot=False, cmap="PuBuGn")
plt.show()

# %% [markdown]
# Now let's focus only on the stations close to our current location. To do that we need to first use the Google API to locate our location and then use a range of X meters to narrow down the dataset to only local stations.

# %%
from _BiciPy.Admin.LocateLogin import locate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-9c2c2fcd6a5e> in <module>()
# ----> 1 from _BiciPy.Admin.LocateLogin import locate
#
# ImportError: No module named '_BiciPy'

# %% [markdown]
# #### 2. Map out the data (static view)

# %% [markdown]
# Create a subset of the dataset that calculates the average available slots / bikes for each station_lat,  station_lon, station_name:

# %%
df_avg_bikes = pd.DataFrame(df.groupby(['station_lat', 'station_lon', 'station_name'])['bikes'].mean().reset_index(name='bikes'))
df_avg_bikes
# Out:
#      station_lat  station_lon  \
# 0      41.357067     2.141563
# 1      41.357338     2.137172
# 2      41.358255     2.143401
# 3      41.360654     2.139132
# 4      41.362135     2.135637
# 5      41.363093     2.139771
# 6      41.363350     2.134144
# 7      41.363350     2.134144
# 8      41.365306     2.135678
# 9      41.365374     2.133087
# 10     41.367504     2.134088
# 11     41.368177     2.139439
# 12     41.368392     2.139726
# 13     41.370297     2.187808
# 14     41.370460     2.138994
# 15     41.371455     2.143882
# 16     41.371515     2.162166
# 17     41.371663     2.180302
# 18     41.371965     2.166871
# 19     41.372154     2.180701
# 20     41.372162     2.156554
# 21     41.372338     2.141875
# 22     41.372536     2.129487
# 23     41.372891     2.154471
# 24     41.373509     2.171002
# 25     41.373698     2.188927
# 26     41.373764     2.161632
# 27     41.374152     2.148154
# 28     41.374213     2.148082
# 29     41.374530     2.142356
# ..           ...          ...
# 389    41.430808     2.160720
# 390    41.431183     2.185852
# 391    41.431593     2.176909
# 392    41.432552     2.184290
# 393    41.433450     2.171500
# 394    41.433897     2.189614
# 395    41.433965     2.175199
# 396    41.434191     2.205886
# 397    41.434630     2.181747
# 398    41.435998     2.189524
# 399    41.436145     2.204634
# 400    41.436180     2.192952
# 401    41.436373     2.170678
# 402    41.436505     2.183877
# 395                   Carrer de l'Escultor Ordóñez, 55  10.153846  14.646154
# 396                          Passeig Enric Sanchís, 33   8.107692  14.446154
# 397                                     Andreu Nin, 22  18.938462  12.092308
# 398                                         Malats, 28  10.476923  14.753846
# 399                                    Sant Adrià, 113  15.723077   6.861538
# 400                              Plaça de l'Estació, 6  13.230769  11.676923
# 401                     Seu del Districte (Nou Barris)  15.738462   7.723077
# 402                     Carrer de Rosselló i Porcel, 1   8.030769  22.153846
# 403                                         Malats, 98   9.030769  13.723077
# 404                                     Marie Curie, 8  16.676923   8.984615
# 405                    Plaça dels Jardins d'Alfàbia, 1   8.892308  15.907692
# 406                                  C/Joan Torras, 28   4.523077  13.569231
# 407                                Carrer Turó Blau, 1   4.830769  16.507692
# 408                           Campana de la Maquinista  20.476923   5.215385
# 409                             Carrer de Bartrina, 14  15.984615  10.015385
# 410                           República Dominicana, 25  20.769231  10.200000
# 411                               Carrer de Palomar, 6  14.338462  10.707692
# 412                              Ciutat d'Asunción, 73  15.000000   8.507692
# 413                        Passeig Torras i Bages, 129  13.076923  11.707692
# 414                             Coronel Monasterio, 26   9.738462  15.415385
# 415                            Plaça Baró de Viver, 22   6.876923  17.369231
# 416                                   Via Barcino, 121  18.400000   7.615385
# 417  Pl. de la Trinitat, 5-7 / amb Mare de Déu de L...   7.707692  18.153846
# 418                                    Via Barcino, 71  13.569231   6.507692
#
# [419 rows x 5 columns]

# %%
df_avg.dtypes
# Out:
# station_lat     float64
# station_lon     float64
# station_name     object
# bikes           float64
# slots           float64
# dtype: object

# %% [markdown]
# Create a function that locates the respective files (those need to be saved in the Credentials folder):

# %%
from pathlib import Path
import os

def locate(filename):
    cwd = Path(os.getcwd())
    cwd_new = str(cwd.parent)+'\Credentials'
        
    for r,d,f in os.walk(cwd_new):
        for files in f:
            if files == filename:
                path = os.path.join(r,files)
              
    with open(path, 'r') as f:
        content = f.readlines()
        content = [x.strip() for x in content]
        
    return(content)

# %% [markdown]
# Get your current location (needed for folium to know what parts of the map to show):

# %%
from geopy.geocoders import GoogleV3

address = locate('home_address.txt')[0]
key = locate('login_googleAPI.txt')[0]

geolocator = GoogleV3(api_key=key)
current_latlon = geolocator.geocode(address)[1]

# %% [markdown]
# Select the lat/lon you want to default the map on and how zoomed you want it to be:

# %%
import folium

folmap_bikes = folium.Map(location=current_latlon, tiles='OpenStreetMap', zoom_start=20)
folmap_slots = folium.Map(location=current_latlon, tiles='OpenStreetMap', zoom_start=20)

# %% [markdown]
# Add to the map the markers of the available stations:

# %%
for idx,i in enumerate(df_avg.station_name):
    popup = folium.Popup(df_avg.station_name[idx]+' / Available bikes: '+str(int(df_avg.bikes[idx]))+' / Available slots: '+str(int(df_avg.slots[idx])), parse_html=True)
    folium.Marker([df_avg.station_lat[idx], df_avg.station_lon[idx]], popup = popup
                 ).add_to(folmap_bikes)

# %%
folmap_bikes
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Option 2: Dynamic View (have an animation of the stations availability)
